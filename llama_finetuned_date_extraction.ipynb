# %% [markdown]
# # Fine-tuning Llama for Datetime Extraction
#
# I'm going to fine-tune a Llama model to convert natural language time expressions into structured datetime formats.

# %%
# !uv pip install transformers unsloth trl
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 83 packages in 967ms
# ⠙ Preparing packages... (0/20)
# ⠙ Preparing packages... (0/20)
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------     0 B/13.88 KiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# datasets   ------------------------------     0 B/480.03 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# datasets   ------------------------------ 14.89 KiB/480.03 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# datasets   ------------------------------ 14.89 KiB/480.03 KiB
# trl        ------------------------------     0 B/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# datasets   ------------------------------ 14.89 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# datasets   ------------------------------ 14.89 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 16.00 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 16.00 KiB/23.50 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 49.80 KiB/162.80 KiB
# msgspec    ------------------------------ 46.91 KiB/205.74 KiB
# unsloth    ------------------------------ 14.92 KiB/292.75 KiB
# datasets   ------------------------------ 60.14 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 79.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 94.39 KiB/23.50 MiB
# xformers   ------------------------------ 78.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# bitsandbytes ------------------------------ 46.91 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 60.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 62.83 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 32.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 14.92 KiB/292.75 KiB
# datasets   ------------------------------ 126.89 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 79.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 94.39 KiB/23.50 MiB
# xformers   ------------------------------ 78.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# bitsandbytes ------------------------------ 286.91 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 60.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 286.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 14.92 KiB/292.75 KiB
# datasets   ------------------------------ 126.89 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 207.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 16.00 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 94.39 KiB/23.50 MiB
# xformers   ------------------------------ 334.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# bitsandbytes ------------------------------ 286.91 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 286.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 284.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 286.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 14.92 KiB/292.75 KiB
# datasets   ------------------------------ 126.89 KiB/480.03 KiB
# trl        ------------------------------ 14.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 207.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 16.00 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 94.39 KiB/23.50 MiB
# xformers   ------------------------------ 334.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# bitsandbytes ------------------------------ 286.91 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 334.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 284.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 286.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 277.77 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# cut-cross-entropy ------------------------------ 14.91 KiB/22.14 KiB
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 30.92 KiB/292.75 KiB
# datasets   ------------------------------ 142.89 KiB/480.03 KiB
# trl        ------------------------------ 30.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 223.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 78.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 27.01 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 526.39 KiB/23.50 MiB
# xformers   ------------------------------ 334.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------     0 B/53.70 MiB
# bitsandbytes ------------------------------ 286.91 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 334.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 284.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 286.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 277.77 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 62.92 KiB/292.75 KiB
# datasets   ------------------------------ 142.89 KiB/480.03 KiB
# trl        ------------------------------ 30.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 383.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 94.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 189.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 526.39 KiB/23.50 MiB
# xformers   ------------------------------ 462.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/53.70 MiB
# bitsandbytes ------------------------------ 472.56 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 462.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 460.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 478.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 453.77 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# tyro       ------------------------------ 46.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 62.92 KiB/292.75 KiB
# datasets   ------------------------------ 188.97 KiB/480.03 KiB
# trl        ------------------------------ 30.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 383.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 94.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 189.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 526.39 KiB/23.50 MiB
# xformers   ------------------------------ 462.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/53.70 MiB
# bitsandbytes ------------------------------ 472.56 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 462.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 460.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 478.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 453.77 KiB/346.60 MiB
# ⠹ Preparing packages... (3/20)
# tyro       ------------------------------ 62.89 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 65.80 KiB/162.80 KiB
# unsloth    ------------------------------ 62.92 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 30.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 479.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 94.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 413.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 797.79 KiB/23.50 MiB
# xformers   ------------------------------ 718.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 16.00 KiB/53.70 MiB
# bitsandbytes ------------------------------ 680.56 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 734.95 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 716.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 686.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 549.77 KiB/346.60 MiB
# ⠹ Preparing packages... (3/20)
# tyro       ------------------------------ 94.79 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 142.88 KiB/162.80 KiB
# unsloth    ------------------------------ 78.92 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 46.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 479.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 94.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 701.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 990.39 KiB/23.50 MiB
# xformers   ------------------------------ 942.91 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 48.00 KiB/53.70 MiB
# bitsandbytes ------------------------------ 903.41 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 926.39 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1004.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 974.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 901.77 KiB/346.60 MiB
# ⠹ Preparing packages... (3/20)
# tyro       ------------------------------ 110.68 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 158.88 KiB/162.80 KiB
# unsloth    ------------------------------ 78.92 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 46.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 495.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 110.36 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 701.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.12 MiB/23.50 MiB
# xformers   ------------------------------ 1.12 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 492.13 KiB/53.70 MiB
# bitsandbytes ------------------------------ 1.05 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.12 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1004.99 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 974.16 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.09 MiB/346.60 MiB
# ⠹ Preparing packages... (3/20)
# tyro       ------------------------------ 110.68 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 162.80 KiB/162.80 KiB
# unsloth    ------------------------------ 78.92 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 46.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 543.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 142.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 925.45 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.18 MiB/23.50 MiB
# xformers   ------------------------------ 1.31 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 956.03 KiB/53.70 MiB
# bitsandbytes ------------------------------ 1.13 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.20 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.17 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.09 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# tyro       ------------------------------ 110.68 KiB/125.98 KiB
# unsloth    ------------------------------ 78.92 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 46.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 543.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 142.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.10 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.37 MiB/23.50 MiB
# xformers   ------------------------------ 1.31 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 956.03 KiB/53.70 MiB
# bitsandbytes ------------------------------ 1.35 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.34 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.37 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.30 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# tyro       ------------------------------ 110.68 KiB/125.98 KiB
# unsloth    ------------------------------ 93.56 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 62.86 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 575.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 142.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.31 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.37 MiB/23.50 MiB
# xformers   ------------------------------ 1.31 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.20 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.60 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.55 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.39 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.45 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.30 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# tyro       ------------------------------ 125.98 KiB/125.98 KiB
# unsloth    ------------------------------ 125.56 KiB/292.75 KiB
# datasets   ------------------------------ 302.89 KiB/480.03 KiB
# trl        ------------------------------ 78.86 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 575.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 174.46 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.31 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.62 MiB/23.50 MiB
# xformers   ------------------------------ 1.53 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.42 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.74 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.61 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.57 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.64 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# tyro       ------------------------------ 125.98 KiB/125.98 KiB
# unsloth    ------------------------------ 125.56 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 78.86 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 591.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.01 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.56 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.81 MiB/23.50 MiB
# xformers   ------------------------------ 1.76 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.42 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.74 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.81 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.70 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# unsloth    ------------------------------ 125.56 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 78.86 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 591.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.86 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.56 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.81 MiB/23.50 MiB
# xformers   ------------------------------ 1.76 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.42 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.74 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.81 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.70 MiB/346.60 MiB
# ⠸ Preparing packages... (3/20)
# unsloth    ------------------------------ 254.07 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 78.86 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 591.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.86 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.56 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/23.50 MiB
# xformers   ------------------------------ 1.76 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.64 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.97 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.79 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 270.07 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 94.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 591.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.00 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/23.50 MiB
# xformers   ------------------------------ 2.00 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.64 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.07 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.97 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.96 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 286.07 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 94.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.00 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.15 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/23.50 MiB
# xformers   ------------------------------ 2.00 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.64 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.07 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.97 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.96 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 286.07 KiB/292.75 KiB
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 94.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.00 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.18 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.00 MiB/23.50 MiB
# xformers   ------------------------------ 2.23 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.87 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.07 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.34 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# datasets   ------------------------------ 318.89 KiB/480.03 KiB
# trl        ------------------------------ 126.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.34 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.18 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.30 MiB/23.50 MiB
# xformers   ------------------------------ 2.36 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.87 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.42 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.34 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 126.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.34 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.18 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.30 MiB/23.50 MiB
# xformers   ------------------------------ 2.36 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.87 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.42 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.34 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 126.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.60 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.43 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.30 MiB/23.50 MiB
# xformers   ------------------------------ 2.81 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.87 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.82 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.38 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.44 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.34 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 126.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 623.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.43 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.71 MiB/23.50 MiB
# xformers   ------------------------------ 2.81 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.26 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.82 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.53 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.76 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.38 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.75 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 142.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 639.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.73 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.52 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.06 MiB/23.50 MiB
# xformers   ------------------------------ 2.81 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.26 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.82 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.73 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.82 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.75 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 142.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 639.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.00 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.52 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.08 MiB/23.50 MiB
# xformers   ------------------------------ 2.84 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.63 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.19 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.73 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.15 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.12 MiB/346.60 MiB
# ⠦ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 142.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 639.93 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.05 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.89 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.08 MiB/23.50 MiB
# xformers   ------------------------------ 3.23 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.63 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.19 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.12 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.15 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.12 MiB/346.60 MiB
# ⠦ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 142.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 863.02 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.89 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.47 MiB/23.50 MiB
# xformers   ------------------------------ 3.23 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.98 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.19 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.12 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.42 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.12 MiB/346.60 MiB
# ⠦ Preparing packages... (6/20)
# datasets   ------------------------------ 334.89 KiB/480.03 KiB
# trl        ------------------------------ 142.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 863.02 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.89 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.47 MiB/23.50 MiB
# xformers   ------------------------------ 3.27 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.98 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.19 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.53 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.61 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.55 MiB/346.60 MiB
# ⠦ Preparing packages... (6/20)
# datasets   ------------------------------ 350.89 KiB/480.03 KiB
# trl        ------------------------------ 158.89 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 863.02 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.00 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.47 MiB/23.50 MiB
# xformers   ------------------------------ 3.62 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.98 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.53 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.61 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.55 MiB/346.60 MiB
# ⠧ Preparing packages... (6/20)
# datasets   ------------------------------ 350.89 KiB/480.03 KiB
# trl        ------------------------------ 158.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.00 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.47 MiB/23.50 MiB
# xformers   ------------------------------ 3.62 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.98 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.53 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.61 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.55 MiB/346.60 MiB
# ⠧ Preparing packages... (6/20)
# datasets   ------------------------------ 350.89 KiB/480.03 KiB
# trl        ------------------------------ 158.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.51 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.00 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.59 MiB/23.50 MiB
# xformers   ------------------------------ 4.03 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.98 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.06 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.53 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.61 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.89 MiB/346.60 MiB
# ⠧ Preparing packages... (6/20)
# datasets   ------------------------------ 366.89 KiB/480.03 KiB
# trl        ------------------------------ 158.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.97 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.36 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.94 MiB/23.50 MiB
# xformers   ------------------------------ 4.03 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.38 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.06 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.92 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.00 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.89 MiB/346.60 MiB
# ⠧ Preparing packages... (6/20)
# datasets   ------------------------------ 382.89 KiB/480.03 KiB
# trl        ------------------------------ 190.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.97 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.59 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.94 MiB/23.50 MiB
# xformers   ------------------------------ 4.03 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.38 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.06 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.92 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.26 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.40 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.89 MiB/346.60 MiB
# ⠧ Preparing packages... (6/20)
# datasets   ------------------------------ 382.89 KiB/480.03 KiB
# trl        ------------------------------ 190.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.97 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.75 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.97 MiB/23.50 MiB
# xformers   ------------------------------ 4.47 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.79 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.92 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.26 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.40 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.34 MiB/346.60 MiB
# ⠇ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 190.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.37 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.75 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.39 MiB/23.50 MiB
# xformers   ------------------------------ 4.47 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.79 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.26 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.40 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.34 MiB/346.60 MiB
# ⠇ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 190.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.37 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.22 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.50 MiB/23.50 MiB
# xformers   ------------------------------ 4.47 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.79 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.80 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.40 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.78 MiB/346.60 MiB
# ⠇ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 190.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.22 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.75 MiB/23.50 MiB
# xformers   ------------------------------ 4.47 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.24 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.88 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.80 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.61 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.78 MiB/346.60 MiB
# ⠇ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 206.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 4.76 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.51 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.75 MiB/23.50 MiB
# xformers   ------------------------------ 4.94 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.24 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.88 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.80 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.83 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.78 MiB/346.60 MiB
# ⠋ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 206.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.11 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.07 MiB/23.50 MiB
# xformers   ------------------------------ 4.94 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.51 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.88 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.80 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.16 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.83 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.78 MiB/346.60 MiB
# ⠋ Preparing packages... (7/20)
# datasets   ------------------------------ 398.89 KiB/480.03 KiB
# trl        ------------------------------ 206.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.11 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.07 MiB/23.50 MiB
# xformers   ------------------------------ 4.97 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.67 MiB/53.70 MiB
# bitsandbytes ------------------------------ 5.34 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.15 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.16 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.83 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.78 MiB/346.60 MiB
# ⠋ Preparing packages... (7/20)
# datasets   ------------------------------ 460.91 KiB/480.03 KiB
# trl        ------------------------------ 206.89 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 5.11 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.16 MiB/23.50 MiB
# xformers   ------------------------------ 5.48 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.67 MiB/53.70 MiB
# bitsandbytes ------------------------------ 5.34 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.22 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.16 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.20 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.16 MiB/346.60 MiB
# ⠋ Preparing packages... (7/20)
# datasets   ------------------------------ 460.91 KiB/480.03 KiB
# ...
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 303.84 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 306.55 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 309.89 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 314.89 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 316.92 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 320.17 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 322.14 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 323.72 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 330.08 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 333.55 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 336.17 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 340.02 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 343.36 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 262.50 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 264.50 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 265.05 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 266.56 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 268.98 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 271.06 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 272.29 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 274.05 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 276.02 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 278.78 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 280.89 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 283.90 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 285.36 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 288.46 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 290.91 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 293.08 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 295.02 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 296.56 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 298.50 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 300.56 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 302.11 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 303.84 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 306.55 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 309.89 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 314.89 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 316.92 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 320.17 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 322.14 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 323.72 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 330.08 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 333.55 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 336.17 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 340.02 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 343.36 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 346.17 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# ⠧ Preparing packages... (18/20)
# ⠧ Preparing packages... (18/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 346.17 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# ⠧ Preparing packages... (18/20)
# ⠧ Preparing packages... (18/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# Prepared 20 packages in 35.35s
# Uninstalled 11 packages in 50ms
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# Prepared 20 packages in 35.35s
# Uninstalled 11 packages in 50ms
# Installed 20 packages in 54ms
#  + bitsandbytes==0.46.1
#  + cut-cross-entropy==25.1.1
#  - datasets==4.0.0
#  + datasets==3.6.0
#  + msgspec==0.19.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + shtab==1.7.2
#  + trl==0.20.0
#  + tyro==0.9.27
#  + unsloth==2025.8.1
#  + unsloth-zoo==2025.8.1
#  + xformers==0.0.29.post3
# Installed 20 packages in 54ms
#  + bitsandbytes==0.46.1
#  + cut-cross-entropy==25.1.1
#  - datasets==4.0.0
#  + datasets==3.6.0
#  + msgspec==0.19.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + shtab==1.7.2
#  + trl==0.20.0
#  + tyro==0.9.27
#  + unsloth==2025.8.1
#  + unsloth-zoo==2025.8.1
#  + xformers==0.0.29.post3

# %%
import torch
import json
from unsloth import FastLanguageModel
from datasets import Dataset
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth.chat_templates import get_chat_template
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ## Loading the Base Model
#
# I'm loading the Llama 3.2 3B Instruct model with 4-bit quantization to save memory:

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=2048,
    load_in_4bit=True
 )
# Out:
# ==((====))==  Unsloth 2025.8.1: Fast Llama patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %% [markdown]
# ## Setting up LoRA Adapter
#
# I'm configuring the model with LoRA (Low-Rank Adaptation) for efficient fine-tuning and setting up the chat template:

# %%
#r is rank on low rank adaptation, r=16 is perfect balance between high and low ranks
model = FastLanguageModel.get_peft_model(
    model, r=16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)

tokenizer = get_chat_template(tokenizer, chat_template="llama-3.1")
# Out:
# Unsloth 2025.8.1 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# Unsloth 2025.8.1 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %% [markdown]
# ## Data Loading and Processing
#
# I'm creating functions to load datetime conversion data from a JSONL file and format it for training:

# %%
def load_datetime_data(file_path):
    """Load datetime conversion data from text file"""
    conversations = []

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    data = json.loads(line)

                    # Create conversation format
                    conversation = [
                        {
                            "role": "user",
                            "content": f"Convert the following natural language time expression to datetime format: '{data['input']}'"
                        },
                        {
                            "role": "assistant",
                            "content": json.dumps(data['output'], indent=2)
                        }
                    ]
                    conversations.append(conversation)

                except json.JSONDecodeError:
                    print(f"Skipping invalid JSON line: {line}")
                    continue

    return conversations

def create_training_dataset(conversations):
    """Convert conversations to training format"""
    formatted_texts = []

    for conversation in conversations:
        # Apply chat template to each conversation
        formatted_text = tokenizer.apply_chat_template(
            conversation,
            tokenize=False,
            add_generation_prompt=False
        )
        formatted_texts.append(formatted_text)

    # Create dataset
    dataset = Dataset.from_dict({"text": formatted_texts})
    return dataset

# Load your datetime data (replace with your actual file path)
print("Loading datetime conversion data...")
conversations = load_datetime_data("/content/time_parsing_dataset.jsonl")
print(f"Loaded {len(conversations)} training examples")

# Create training dataset
dataset = create_training_dataset(conversations)
print("Dataset created successfully")
print(f"Sample training text:\n{dataset[0]['text'][:500]}...")
# Out:
# Loading datetime conversion data...
# Loaded 200 training examples
# Dataset created successfully
# Sample training text:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 July 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Convert the following natural language time expression to datetime format: 'this morning at 7-10'<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# {
#   "start": "2025-08-05T07:00:00",
#   "end": "2025-08-05T10:00:00"
# }<|eot_id|>...

# %% [markdown]
# ## Setting up the Trainer
#
# I'm configuring the SFTTrainer with optimized parameters for better learning:

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=10,
        max_steps=100,  # Increased for better learning
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=10,
        output_dir="datetime_model_outputs",
        save_steps=50,
        dataloader_drop_last=False,
    ),
)
# Out:
# Unsloth: Tokenizing ["text"]:   0%|          | 0/200 [00:00<?, ? examples/s]

# %% [markdown]
# ## Training the Model
#
# Now I'm starting the training process, saving the fine-tuned model

# %%
print("Starting training...")
trainer.train()

# Save the fine-tuned model
print("Saving fine-tuned model...")
model.save_pretrained("datetime_finetuned_model")
tokenizer.save_pretrained("datetime_finetuned_model")
# Out:
# Starting training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 200 | Num Epochs = 4 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vvishus1717 (vvishus17) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250804_215319-clvxk7kr</code>
# Syncing run <strong><a href='https://wandb.ai/vvishus17/huggingface/runs/clvxk7kr' target="_blank">datetime_model_outputs</a></strong> to <a href='https://wandb.ai/vvishus17/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vvishus17/huggingface' target="_blank">https://wandb.ai/vvishus17/huggingface</a>
#  View run at <a href='https://wandb.ai/vvishus17/huggingface/runs/clvxk7kr' target="_blank">https://wandb.ai/vvishus17/huggingface/runs/clvxk7kr</a>
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 03:31, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.695400</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.741100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.468200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.403900</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.303600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.214900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.191800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.173800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.159800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.159000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving fine-tuned model...
# ('datetime_finetuned_model/tokenizer_config.json',
#  'datetime_finetuned_model/special_tokens_map.json',
#  'datetime_finetuned_model/chat_template.jinja',
#  'datetime_finetuned_model/tokenizer.json')

# %% [markdown]
# ## Additional Testing
#
# I'm running additional tests with the fine-tuned model to verify its performance:

# %%
# Load model for inference
print("Loading model for inference...")
inference_model, inference_tokenizer = FastLanguageModel.from_pretrained(
    model_name="./datetime_finetuned_model",
    max_seq_length=2048,
    load_in_4bit=True
)

# Test the fine-tuned model
test_prompts = [
    "tomorrow at 3 PM",
    "next Friday evening",
    "in 2 hours",
    "last Monday morning",
    "Christmas Day 2025"
]

print("\n" + "="*50)
print("Testing fine-tuned model:")
print("="*50)

for prompt in test_prompts:
    formatted_prompt = inference_tokenizer.apply_chat_template(
        [{
            "role": "user",
            "content": f"Convert the following natural language time expression to datetime format: '{prompt}'"
        }],
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = inference_tokenizer(formatted_prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        generated_ids = inference_model.generate(
            **model_inputs,
            max_new_tokens=256,
            temperature=0.1,  # Lower temperature for more consistent output
            do_sample=True,
            pad_token_id=inference_tokenizer.pad_token_id,
            eos_token_id=inference_tokenizer.eos_token_id,
        )

    # Extract only the generated part (remove input prompt)
    generated_ids = generated_ids[0][len(model_inputs.input_ids[0]):]
    response = inference_tokenizer.decode(generated_ids, skip_special_tokens=True)

    print(f"\nInput: {prompt}")
    print(f"Output: {response.strip()}")
    print("-" * 30)

print("\nFine-tuning completed successfully!")
# Out:
# Loading model for inference...
# ==((====))==  Unsloth 2025.8.1: Fast Llama patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
#
# ==================================================
# Testing fine-tuned model:
# ==================================================
#
# Input: tomorrow at 3 PM
# Output: {
#   "start": "2025-08-06T15:00:00",
#   "end": "2025-08-06T15:00:00"
# }
# ------------------------------
#
# Input: next Friday evening
# Output: {
#   "start": "2025-08-15T18:00:00",
#   "end": "2025-08-15T21:00:00"
# }
# ------------------------------
#
# Input: in 2 hours
# Output: {
#   "start": "2025-08-05T14:00:00",
#   "end": "2025-08-05T14:00:00"
# }
# ------------------------------
#
# Input: last Monday morning
# Output: {
#   "start": "2025-08-11T06:00:00",
#   "end": "2025-08-11T06:00:00"
# }
# ------------------------------
#
# Input: Christmas Day 2025
# Output: {
#   "start": "2025-12-25T00:00:00",
#   "end": "2025-12-25T23:59:59"
# }
# ------------------------------
#
# Fine-tuning completed successfully!
