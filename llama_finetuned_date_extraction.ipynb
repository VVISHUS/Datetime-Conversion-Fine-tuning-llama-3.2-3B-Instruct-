# %%
# !uv pip install transformers unsloth trl
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 83 packages in 754ms
# ⠙ Preparing packages... (0/20)
# ⠙ Preparing packages... (0/20)
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# ⠙ Preparing packages... (0/20)
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# ⠙ Preparing packages... (0/20)
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------     0 B/13.88 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------     0 B/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------     0 B/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# xformers   ------------------------------     0 B/41.35 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# xformers   ------------------------------     0 B/41.35 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# nvidia-cufft-cu12 ------------------------------     0 B/201.66 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# msgspec    ------------------------------     0 B/205.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# xformers   ------------------------------     0 B/41.35 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# nvidia-cufft-cu12 ------------------------------     0 B/201.66 MiB
# ⠙ Preparing packages... (0/20)
# shtab      ------------------------------ 13.88 KiB/13.88 KiB
# tyro       ------------------------------ 14.88 KiB/125.98 KiB
# msgspec    ------------------------------     0 B/205.74 KiB
# datasets   ------------------------------     0 B/480.03 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# xformers   ------------------------------     0 B/41.35 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# nvidia-cufft-cu12 ------------------------------     0 B/201.66 MiB
# ⠙ Preparing packages... (0/20)
# tyro       ------------------------------ 30.88 KiB/125.98 KiB
# msgspec    ------------------------------     0 B/205.74 KiB
# datasets   ------------------------------     0 B/480.03 KiB
# nvidia-cuda-runtime-cu12 ------------------------------     0 B/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------     0 B/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------     0 B/23.50 MiB
# xformers   ------------------------------     0 B/41.35 MiB
# bitsandbytes ------------------------------     0 B/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------     0 B/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------     0 B/197.84 MiB
# nvidia-cufft-cu12 ------------------------------     0 B/201.66 MiB
# ⠙ Preparing packages... (0/20)
# cut-cross-entropy ------------------------------ 16.00 KiB/22.14 KiB
# tyro       ------------------------------ 62.88 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 114.33 KiB/162.80 KiB
# msgspec    ------------------------------ 14.91 KiB/205.74 KiB
# unsloth    ------------------------------ 14.91 KiB/292.75 KiB
# datasets   ------------------------------ 78.88 KiB/480.03 KiB
# trl        ------------------------------ 15.41 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 1.28 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 16.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 252.47 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 302.05 KiB/23.50 MiB
# xformers   ------------------------------ 72.83 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 60.31 KiB/53.70 MiB
# bitsandbytes ------------------------------ 16.00 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 16.00 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 16.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# cut-cross-entropy ------------------------------ 16.00 KiB/22.14 KiB
# tyro       ------------------------------ 62.88 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 114.33 KiB/162.80 KiB
# msgspec    ------------------------------ 14.91 KiB/205.74 KiB
# unsloth    ------------------------------ 14.91 KiB/292.75 KiB
# datasets   ------------------------------ 94.88 KiB/480.03 KiB
# trl        ------------------------------ 15.41 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 17.28 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 48.00 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 412.47 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 414.05 KiB/23.50 MiB
# xformers   ------------------------------ 366.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 124.31 KiB/53.70 MiB
# bitsandbytes ------------------------------ 16.00 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 16.00 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 32.00 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 16.00 KiB/346.60 MiB
# ⠙ Preparing packages... (0/20)
# cut-cross-entropy ------------------------------ 16.00 KiB/22.14 KiB
# tyro       ------------------------------ 78.88 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 143.89 KiB/162.80 KiB
# msgspec    ------------------------------ 190.91 KiB/205.74 KiB
# unsloth    ------------------------------ 30.91 KiB/292.75 KiB
# datasets   ------------------------------ 126.88 KiB/480.03 KiB
# trl        ------------------------------ 15.41 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 33.28 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 79.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 428.47 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 446.05 KiB/23.50 MiB
# xformers   ------------------------------ 446.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 428.31 KiB/53.70 MiB
# bitsandbytes ------------------------------ 429.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 429.38 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 381.69 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 16.00 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 48.00 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# cut-cross-entropy ------------------------------ 22.14 KiB/22.14 KiB
# tyro       ------------------------------ 94.88 KiB/125.98 KiB
# unsloth-zoo ------------------------------ 159.89 KiB/162.80 KiB
# msgspec    ------------------------------ 205.74 KiB/205.74 KiB
# unsloth    ------------------------------ 78.91 KiB/292.75 KiB
# datasets   ------------------------------ 142.88 KiB/480.03 KiB
# trl        ------------------------------ 25.15 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 238.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 111.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 561.76 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 590.05 KiB/23.50 MiB
# xformers   ------------------------------ 590.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 492.21 KiB/53.70 MiB
# bitsandbytes ------------------------------ 541.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 532.70 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 525.69 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 622.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 588.93 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# cut-cross-entropy ------------------------------ 22.14 KiB/22.14 KiB
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# msgspec    ------------------------------ 205.74 KiB/205.74 KiB
# unsloth    ------------------------------ 78.91 KiB/292.75 KiB
# datasets   ------------------------------ 174.88 KiB/480.03 KiB
# trl        ------------------------------ 41.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 254.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 127.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 733.35 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 798.70 KiB/23.50 MiB
# xformers   ------------------------------ 846.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 750.39 KiB/53.70 MiB
# bitsandbytes ------------------------------ 749.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 749.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 749.47 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 814.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 765.03 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# cut-cross-entropy ------------------------------ 22.14 KiB/22.14 KiB
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# msgspec    ------------------------------ 205.74 KiB/205.74 KiB
# unsloth    ------------------------------ 91.48 KiB/292.75 KiB
# datasets   ------------------------------ 190.88 KiB/480.03 KiB
# trl        ------------------------------ 41.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 286.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 127.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 733.35 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 798.70 KiB/23.50 MiB
# xformers   ------------------------------ 846.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 750.39 KiB/53.70 MiB
# bitsandbytes ------------------------------ 749.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 749.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 749.47 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 814.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 765.03 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# msgspec    ------------------------------ 205.74 KiB/205.74 KiB
# unsloth    ------------------------------ 91.48 KiB/292.75 KiB
# datasets   ------------------------------ 190.88 KiB/480.03 KiB
# trl        ------------------------------ 41.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 286.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 127.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 733.35 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 798.70 KiB/23.50 MiB
# xformers   ------------------------------ 846.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 750.39 KiB/53.70 MiB
# bitsandbytes ------------------------------ 749.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 749.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 749.47 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 814.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 765.03 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# unsloth    ------------------------------ 91.48 KiB/292.75 KiB
# datasets   ------------------------------ 206.88 KiB/480.03 KiB
# trl        ------------------------------ 57.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 302.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 127.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 733.35 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 798.70 KiB/23.50 MiB
# xformers   ------------------------------ 846.03 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 750.39 KiB/53.70 MiB
# bitsandbytes ------------------------------ 749.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 749.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 749.47 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 814.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 765.03 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# unsloth    ------------------------------ 91.48 KiB/292.75 KiB
# datasets   ------------------------------ 222.88 KiB/480.03 KiB
# trl        ------------------------------ 57.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 302.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 143.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 733.35 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 999.84 KiB/23.50 MiB
# xformers   ------------------------------ 896.00 KiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 750.39 KiB/53.70 MiB
# bitsandbytes ------------------------------ 941.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 973.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 749.47 KiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1022.42 KiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 989.03 KiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# unsloth    ------------------------------ 107.37 KiB/292.75 KiB
# datasets   ------------------------------ 226.05 KiB/480.03 KiB
# trl        ------------------------------ 57.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 334.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 143.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 940.47 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.11 MiB/23.50 MiB
# xformers   ------------------------------ 1.23 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 956.31 KiB/53.70 MiB
# bitsandbytes ------------------------------ 941.31 KiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 973.49 KiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.16 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.18 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.21 MiB/346.60 MiB
# ⠹ Preparing packages... (1/20)
# tyro       ------------------------------ 110.88 KiB/125.98 KiB
# unsloth    ------------------------------ 107.37 KiB/292.75 KiB
# datasets   ------------------------------ 302.78 KiB/480.03 KiB
# trl        ------------------------------ 57.05 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 334.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 159.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.11 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.41 MiB/23.50 MiB
# xformers   ------------------------------ 1.47 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.37 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.09 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.25 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.34 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.46 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.43 MiB/346.60 MiB
# ⠸ Preparing packages... (4/20)
# tyro       ------------------------------ 125.50 KiB/125.98 KiB
# unsloth    ------------------------------ 107.37 KiB/292.75 KiB
# datasets   ------------------------------ 302.78 KiB/480.03 KiB
# trl        ------------------------------ 64.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 350.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 175.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.39 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.46 MiB/23.50 MiB
# xformers   ------------------------------ 1.64 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.43 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.61 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.67 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.58 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.66 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.61 MiB/346.60 MiB
# ⠸ Preparing packages... (4/20)
# tyro       ------------------------------ 125.50 KiB/125.98 KiB
# unsloth    ------------------------------ 107.37 KiB/292.75 KiB
# datasets   ------------------------------ 302.78 KiB/480.03 KiB
# trl        ------------------------------ 64.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 574.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 175.39 KiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.58 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.66 MiB/23.50 MiB
# xformers   ------------------------------ 1.73 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.59 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.61 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.67 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.77 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.61 MiB/346.60 MiB
# ⠸ Preparing packages... (4/20)
# tyro       ------------------------------ 125.50 KiB/125.98 KiB
# unsloth    ------------------------------ 123.37 KiB/292.75 KiB
# datasets   ------------------------------ 302.78 KiB/480.03 KiB
# trl        ------------------------------ 64.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 574.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.34 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.84 MiB/23.50 MiB
# xformers   ------------------------------ 1.94 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.77 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.87 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.77 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.81 MiB/346.60 MiB
# ⠸ Preparing packages... (4/20)
# unsloth    ------------------------------ 123.37 KiB/292.75 KiB
# datasets   ------------------------------ 302.78 KiB/480.03 KiB
# trl        ------------------------------ 64.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 574.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.84 MiB/23.50 MiB
# xformers   ------------------------------ 1.94 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 1.77 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.87 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.77 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.81 MiB/346.60 MiB
# ⠸ Preparing packages... (4/20)
# unsloth    ------------------------------ 123.37 KiB/292.75 KiB
# datasets   ------------------------------ 318.78 KiB/480.03 KiB
# trl        ------------------------------ 80.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 590.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.10 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.84 MiB/23.50 MiB
# xformers   ------------------------------ 2.02 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.06 MiB/53.70 MiB
# bitsandbytes ------------------------------ 1.79 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.14 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.77 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.88 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.09 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 139.37 KiB/292.75 KiB
# datasets   ------------------------------ 318.78 KiB/480.03 KiB
# trl        ------------------------------ 96.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 606.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.10 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.39 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.45 MiB/23.50 MiB
# xformers   ------------------------------ 2.23 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.06 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.01 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.14 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.09 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.23 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 142.91 KiB/292.75 KiB
# datasets   ------------------------------ 334.88 KiB/480.03 KiB
# trl        ------------------------------ 192.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 606.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.50 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.39 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.45 MiB/23.50 MiB
# xformers   ------------------------------ 2.61 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.23 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.36 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.40 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.47 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 142.91 KiB/292.75 KiB
# datasets   ------------------------------ 392.56 KiB/480.03 KiB
# trl        ------------------------------ 336.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 621.23 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.84 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.78 MiB/23.50 MiB
# xformers   ------------------------------ 2.94 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.62 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.59 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.76 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.36 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.80 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.47 MiB/346.60 MiB
# ⠼ Preparing packages... (5/20)
# unsloth    ------------------------------ 267.71 KiB/292.75 KiB
# trl        ------------------------------ 400.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.23 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.87 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.87 MiB/23.50 MiB
# xformers   ------------------------------ 3.00 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.86 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.86 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.90 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.84 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# unsloth    ------------------------------ 267.71 KiB/292.75 KiB
# trl        ------------------------------ 400.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.23 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.01 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.81 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.87 MiB/23.50 MiB
# xformers   ------------------------------ 3.00 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.86 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.86 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.90 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.17 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# unsloth    ------------------------------ 267.71 KiB/292.75 KiB
# trl        ------------------------------ 400.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.23 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.30 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.22 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.87 MiB/23.50 MiB
# xformers   ------------------------------ 3.00 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 2.86 MiB/53.70 MiB
# bitsandbytes ------------------------------ 2.86 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.97 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.13 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.17 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# unsloth    ------------------------------ 270.91 KiB/292.75 KiB
# trl        ------------------------------ 432.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 862.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.22 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.21 MiB/23.50 MiB
# xformers   ------------------------------ 3.39 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.01 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.97 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.23 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.17 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# unsloth    ------------------------------ 270.91 KiB/292.75 KiB
# trl        ------------------------------ 432.00 KiB/492.74 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 862.60 KiB/863.02 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.50 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.62 MiB/23.50 MiB
# xformers   ------------------------------ 3.83 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# unsloth    ------------------------------ 270.91 KiB/292.75 KiB
# trl        ------------------------------ 432.00 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.62 MiB/23.50 MiB
# xformers   ------------------------------ 3.83 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# trl        ------------------------------ 432.00 KiB/492.74 KiB
# nvidia-cuda-cupti-cu12 ------------------------------ 3.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.62 MiB/23.50 MiB
# xformers   ------------------------------ 3.83 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 3.67 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 3.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 3.62 MiB/23.50 MiB
# xformers   ------------------------------ 3.83 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 3.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.50 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠴ Preparing packages... (6/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 3.70 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.01 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.06 MiB/23.50 MiB
# xformers   ------------------------------ 3.83 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.05 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 3.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.62 MiB/346.60 MiB
# ⠦ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 4.06 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.01 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.06 MiB/23.50 MiB
# xformers   ------------------------------ 4.80 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 3.36 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.05 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 3.56 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 3.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.11 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 3.97 MiB/346.60 MiB
# ⠦ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 4.56 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.45 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.49 MiB/23.50 MiB
# xformers   ------------------------------ 4.91 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.00 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.42 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.44 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.34 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.14 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.35 MiB/346.60 MiB
# ⠦ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 4.98 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.64 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.64 MiB/23.50 MiB
# xformers   ------------------------------ 5.44 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.56 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.62 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.57 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 4.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.57 MiB/346.60 MiB
# ⠦ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 4.98 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.93 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 4.98 MiB/23.50 MiB
# xformers   ------------------------------ 5.72 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 4.72 MiB/53.70 MiB
# bitsandbytes ------------------------------ 4.92 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 4.83 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 4.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.06 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 4.88 MiB/346.60 MiB
# ⠧ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 4.98 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 4.93 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.42 MiB/23.50 MiB
# xformers   ------------------------------ 6.19 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 5.03 MiB/53.70 MiB
# bitsandbytes ------------------------------ 5.39 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.23 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.47 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.34 MiB/346.60 MiB
# ⠧ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 5.41 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.59 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.42 MiB/23.50 MiB
# xformers   ------------------------------ 6.19 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 5.03 MiB/53.70 MiB
# bitsandbytes ------------------------------ 5.64 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.37 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.36 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.68 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.34 MiB/346.60 MiB
# ⠧ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 5.66 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.59 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 5.84 MiB/23.50 MiB
# xformers   ------------------------------ 6.89 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 5.72 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.11 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 5.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 5.68 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.93 MiB/346.60 MiB
# ⠇ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 6.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 5.84 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.05 MiB/23.50 MiB
# xformers   ------------------------------ 6.89 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 5.72 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.11 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.93 MiB/346.60 MiB
# ⠇ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 6.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.00 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.05 MiB/23.50 MiB
# xformers   ------------------------------ 6.98 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 5.72 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.11 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 5.78 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.12 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.93 MiB/346.60 MiB
# ⠇ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 6.14 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.31 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.42 MiB/23.50 MiB
# xformers   ------------------------------ 7.38 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 6.18 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.50 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.01 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 5.93 MiB/346.60 MiB
# ⠇ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 6.61 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.62 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 6.67 MiB/23.50 MiB
# xformers   ------------------------------ 7.38 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 6.18 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.50 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.68 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.19 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 6.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 6.56 MiB/346.60 MiB
# ⠋ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 6.97 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.06 MiB/23.50 MiB
# xformers   ------------------------------ 7.99 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 6.67 MiB/53.70 MiB
# bitsandbytes ------------------------------ 6.94 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.68 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.69 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.11 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.00 MiB/346.60 MiB
# ⠋ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 7.50 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 6.78 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.53 MiB/23.50 MiB
# xformers   ------------------------------ 8.34 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 7.14 MiB/53.70 MiB
# bitsandbytes ------------------------------ 7.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 6.68 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.69 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.11 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.54 MiB/346.60 MiB
# ⠋ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 7.50 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.28 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 7.53 MiB/23.50 MiB
# xformers   ------------------------------ 8.44 MiB/41.35 MiB
# nvidia-curand-cu12 ------------------------------ 7.14 MiB/53.70 MiB
# bitsandbytes ------------------------------ 7.47 MiB/69.49 MiB
# nvidia-cusolver-cu12 ------------------------------ 7.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 6.84 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 7.53 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 7.54 MiB/346.60 MiB
# ⠋ Preparing packages... (9/20)
# nvidia-cuda-cupti-cu12 ------------------------------ 7.50 MiB/13.17 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 7.62 MiB/20.09 MiB
# ...
# ⠙ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 181.98 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 189.39 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.04 MiB/346.60 MiB
# ⠙ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 189.54 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.04 MiB/346.60 MiB
# ⠹ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.04 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.04 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.06 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.07 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.09 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.11 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.72 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.01 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.12 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.73 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.31 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.79 MiB/346.60 MiB
# ⠸ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 182.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.31 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 195.79 MiB/346.60 MiB
# ⠼ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 184.64 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 190.31 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 197.00 MiB/346.60 MiB
# ⠼ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 185.08 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 192.05 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 198.95 MiB/346.60 MiB
# ⠼ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 186.48 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 192.06 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 199.04 MiB/346.60 MiB
# ⠼ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 187.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 194.25 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 200.76 MiB/346.60 MiB
# ⠴ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 190.03 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 195.17 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 202.22 MiB/346.60 MiB
# ⠴ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 191.22 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 196.47 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 204.23 MiB/346.60 MiB
# ⠴ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 191.53 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 196.92 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 205.47 MiB/346.60 MiB
# ⠴ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 194.13 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 198.43 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 206.43 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 195.76 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 199.90 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 207.99 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 196.17 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 201.34 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 210.37 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 197.83 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 201.62 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 211.06 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 197.84 MiB/197.84 MiB
# nvidia-cublas-cu12 ------------------------------ 212.89 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cusparse-cu12 ------------------------------ 197.84 MiB/197.84 MiB
# nvidia-cublas-cu12 ------------------------------ 212.89 MiB/346.60 MiB
# ⠦ Preparing packages... (16/20)
# nvidia-cublas-cu12 ------------------------------ 212.89 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 215.27 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 217.00 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 218.37 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 220.70 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 223.17 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 225.61 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 228.33 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 230.75 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 232.47 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 234.92 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 237.79 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 239.02 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 241.68 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 243.68 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 245.70 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 248.31 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 250.27 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 253.26 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 256.40 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 259.00 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 261.70 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 263.83 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 265.81 MiB/346.60 MiB
# ⠸ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 268.29 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 270.12 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 273.81 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 275.80 MiB/346.60 MiB
# ⠼ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 278.42 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 281.00 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 282.97 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 282.97 MiB/346.60 MiB
# ⠴ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 285.97 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 288.19 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 290.86 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 292.47 MiB/346.60 MiB
# ⠦ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 294.83 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 295.98 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 296.45 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 298.39 MiB/346.60 MiB
# ⠧ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 300.12 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 301.30 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 303.75 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 305.06 MiB/346.60 MiB
# ⠇ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 307.08 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 309.72 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 313.86 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 318.77 MiB/346.60 MiB
# ⠋ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 322.88 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 325.57 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 330.31 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 332.54 MiB/346.60 MiB
# ⠙ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 336.78 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 340.69 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# nvidia-cublas-cu12 ------------------------------ 345.12 MiB/346.60 MiB
# ⠹ Preparing packages... (18/20)
# ⠹ Preparing packages... (18/20)
# ⠹ Preparing packages... (18/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠴ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠹ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠸ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠼ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠦ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠧ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠇ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠋ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# ⠙ Preparing packages... (19/20)
# Prepared 20 packages in 29.01s
# Uninstalled 11 packages in 34ms
# Installed 20 packages in 59ms
#  + bitsandbytes==0.46.1
#  + cut-cross-entropy==25.1.1
#  - datasets==4.0.0
#  + datasets==3.6.0
#  + msgspec==0.19.0
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + shtab==1.7.2
#  + trl==0.20.0
#  + tyro==0.9.27
#  + unsloth==2025.8.1
#  + unsloth-zoo==2025.8.1
#  + xformers==0.0.29.post3

# %%
import torch
import json
from unsloth import FastLanguageModel
from datasets import Dataset
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth.chat_templates import get_chat_template

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Llama-3.2-3B-Instruct",
    max_seq_length=2048,
    load_in_4bit=True
 )
# Out:
# ==((====))==  Unsloth 2025.8.1: Fast Llama patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.35G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]

# %%
#r is rank on low rank adaptation, r=16 is perfect balance between high and low ranks
model = FastLanguageModel.get_peft_model(
    model, r=16,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"]
)

tokenizer = get_chat_template(tokenizer, chat_template="llama-3.1")
# Out:
# Unsloth 2025.8.1 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.

# %%
def load_datetime_data(file_path):
    """Load datetime conversion data from text file"""
    conversations = []

    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if line:
                try:
                    data = json.loads(line)

                    # Create conversation format
                    conversation = [
                        {
                            "role": "user",
                            "content": f"Convert the following natural language time expression to datetime format: '{data['input']}'"
                        },
                        {
                            "role": "assistant",
                            "content": json.dumps(data['output'], indent=2)
                        }
                    ]
                    conversations.append(conversation)

                except json.JSONDecodeError:
                    print(f"Skipping invalid JSON line: {line}")
                    continue

    return conversations

def create_training_dataset(conversations):
    """Convert conversations to training format"""
    formatted_texts = []

    for conversation in conversations:
        # Apply chat template to each conversation
        formatted_text = tokenizer.apply_chat_template(
            conversation,
            tokenize=False,
            add_generation_prompt=False
        )
        formatted_texts.append(formatted_text)

    # Create dataset
    dataset = Dataset.from_dict({"text": formatted_texts})
    return dataset

# Load your datetime data (replace with your actual file path)
print("Loading datetime conversion data...")
conversations = load_datetime_data("/content/time_parsing_dataset.jsonl")
print(f"Loaded {len(conversations)} training examples")

# Create training dataset
dataset = create_training_dataset(conversations)
print("Dataset created successfully")
print(f"Sample training text:\n{dataset[0]['text'][:500]}...")
# Out:
# Loading datetime conversion data...
# Loaded 200 training examples
# Dataset created successfully
# Sample training text:
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 26 July 2024
#
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Convert the following natural language time expression to datetime format: 'this morning at 7-10'<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# {
#   "start": "2025-08-05T07:00:00",
#   "end": "2025-08-05T10:00:00"
# }<|eot_id|>...

# %%
# trainer = SFTTrainer(
#     model = model,
#     train_dataset = dataset,
#     dataset_text_field = "text",
#     max_seq_length = 2048,
#     args=TrainingArguments(
#         per_device_train_batch_size=2,
#         gradient_accumulation_steps=4,
#         warmup_steps=5,
#         max_steps=60,
#         learning_rate=2e-4,
#         fp16=not torch.cuda.is_bf16_supported(),
#         bf16=torch.cuda.is_bf16_supported(),
#         logging_steps=1,
#         output_dir="outputs"
#     ),
# )

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        warmup_steps=10,
        max_steps=100,  # Increased for better learning
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=10,
        output_dir="datetime_model_outputs",
        save_steps=50,
        dataloader_drop_last=False,
    ),
)
# Out:
# Unsloth: Tokenizing ["text"]:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
print("Starting training...")
trainer.train()

# Save the fine-tuned model
print("Saving fine-tuned model...")
model.save_pretrained("datetime_finetuned_model")
tokenizer.save_pretrained("datetime_finetuned_model")

# Load model for inference
print("Loading model for inference...")
inference_model, inference_tokenizer = FastLanguageModel.from_pretrained(
    model_name="./datetime_finetuned_model",
    max_seq_length=2048,
    load_in_4bit=True
)

# Test the fine-tuned model
test_prompts = [
    "tomorrow at 3 PM",
    "next Friday evening",
    "in 2 hours",
    "last Monday morning",
    "Christmas Day 2025"
]

print("\n" + "="*50)
print("Testing fine-tuned model:")
print("="*50)

for prompt in test_prompts:
    formatted_prompt = inference_tokenizer.apply_chat_template(
        [{
            "role": "user",
            "content": f"Convert the following natural language time expression to datetime format: '{prompt}'"
        }],
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = inference_tokenizer(formatted_prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        generated_ids = inference_model.generate(
            **model_inputs,
            max_new_tokens=256,
            temperature=0.1,
            do_sample=True,
            pad_token_id=inference_tokenizer.pad_token_id,
            eos_token_id=inference_tokenizer.eos_token_id,
        )

    # Extract only the generated part (remove input prompt)
    generated_ids = generated_ids[0][len(model_inputs.input_ids[0]):]
    response = inference_tokenizer.decode(generated_ids, skip_special_tokens=True)

    print(f"\nInput: {prompt}")
    print(f"Output: {response.strip()}")
    print("-" * 30)

print("\nFine-tuning completed successfully!")
# Out:
# Starting training...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 200 | Num Epochs = 4 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: vvishus1717 (vvishus17) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250804_211952-30ccbnrm</code>
# Syncing run <strong><a href='https://wandb.ai/vvishus17/huggingface/runs/30ccbnrm' target="_blank">datetime_model_outputs</a></strong> to <a href='https://wandb.ai/vvishus17/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/vvishus17/huggingface' target="_blank">https://wandb.ai/vvishus17/huggingface</a>
#  View run at <a href='https://wandb.ai/vvishus17/huggingface/runs/30ccbnrm' target="_blank">https://wandb.ai/vvishus17/huggingface/runs/30ccbnrm</a>
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 03:27, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.695600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.740900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.468200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.403800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.303500</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.215000</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.191800</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.173800</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.159900</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.159000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving fine-tuned model...
# Loading model for inference...
# ==((====))==  Unsloth 2025.8.1: Fast Llama patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
#
# ==================================================
# Testing fine-tuned model:
# ==================================================
#
# Input: tomorrow at 3 PM
# Output: {
#   "start": "2025-08-06T15:00:00",
#   "end": "2025-08-06T15:00:00"
# }
# ------------------------------
#
# Input: next Friday evening
# Output: {
#   "start": "2025-08-15T18:00:00",
#   "end": "2025-08-15T21:00:00"
# }
# ------------------------------
#
# Input: in 2 hours
# Output: {
#   "start": "2025-08-05T14:00:00",
#   "end": "2025-08-05T14:00:00"
# }
# ------------------------------
#
# Input: last Monday morning
# Output: {
#   "start": "2025-08-11T06:00:00",
#   "end": "2025-08-11T06:00:00"
# }
# ------------------------------
#
# Input: Christmas Day 2025
# Output: {
#   "start": "2025-12-25T00:00:00",
#   "end": "2025-12-25T23:59:59"
# }
# ------------------------------
#
# Fine-tuning completed successfully!

# %%
# Load model for inference
print("Loading model for inference...")
inference_model, inference_tokenizer = FastLanguageModel.from_pretrained(
    model_name="./datetime_finetuned_model",
    max_seq_length=2048,
    load_in_4bit=True
)

# Test the fine-tuned model
test_prompts = [
    "tomorrow at 3 PM",
    "next Friday evening",
    "in 2 hours",
    "last Monday morning",
    "Christmas Day 2025"
]

print("\n" + "="*50)
print("Testing fine-tuned model:")
print("="*50)

for prompt in test_prompts:
    formatted_prompt = inference_tokenizer.apply_chat_template(
        [{
            "role": "user",
            "content": f"Convert the following natural language time expression to datetime format: '{prompt}'"
        }],
        tokenize=False,
        add_generation_prompt=True
    )

    model_inputs = inference_tokenizer(formatted_prompt, return_tensors="pt").to("cuda")

    with torch.no_grad():
        generated_ids = inference_model.generate(
            **model_inputs,
            max_new_tokens=256,
            temperature=0.1,  # Lower temperature for more consistent output
            do_sample=True,
            pad_token_id=inference_tokenizer.pad_token_id,
            eos_token_id=inference_tokenizer.eos_token_id,
        )

    # Extract only the generated part (remove input prompt)
    generated_ids = generated_ids[0][len(model_inputs.input_ids[0]):]
    response = inference_tokenizer.decode(generated_ids, skip_special_tokens=True)

    print(f"\nInput: {prompt}")
    print(f"Output: {response.strip()}")
    print("-" * 30)

print("\nFine-tuning completed successfully!")
# Out:
# Loading model for inference...
# ==((====))==  Unsloth 2025.8.1: Fast Llama patching. Transformers: 4.54.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
#
# ==================================================
# Testing fine-tuned model:
# ==================================================
#
# Input: tomorrow at 3 PM
# Output: {
#   "start": "2025-08-06T15:00:00",
#   "end": "2025-08-06T15:00:00"
# }
# ------------------------------
#
# Input: next Friday evening
# Output: {
#   "start": "2025-08-15T18:00:00",
#   "end": "2025-08-15T21:00:00"
# }
# ------------------------------
#
# Input: in 2 hours
# Output: {
#   "start": "2025-08-05T14:00:00",
#   "end": "2025-08-05T14:00:00"
# }
# ------------------------------
#
# Input: last Monday morning
# Output: {
#   "start": "2025-08-11T06:00:00",
#   "end": "2025-08-11T06:00:00"
# }
# ------------------------------
#
# Input: Christmas Day 2025
# Output: {
#   "start": "2025-12-25T00:00:00",
#   "end": "2025-12-25T23:59:59"
# }
# ------------------------------
#
# Fine-tuning completed successfully!
